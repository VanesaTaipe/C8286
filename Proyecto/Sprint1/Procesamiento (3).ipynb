# %%
import pandas as pd
data=pd.read_csv("/content/tweets_sin_entrenamiento.csv")

# %%
data
# Out:
#                   user_id                 created_at  likes  source  \
# 0     1515220311469621248  2024-06-10 02:03:04+00:00      0     NaN
# 1     1771902488074944512  2024-06-10 02:03:04+00:00      0     NaN
# 2     1075476235449450499  2024-06-10 02:03:04+00:00      0     NaN
# 3              1382805156  2024-06-10 02:03:04+00:00      0     NaN
# 4     1270842720731488265  2024-06-10 02:03:04+00:00      0     NaN
# ...                   ...                        ...    ...     ...
# 9023           1730171166  2024-06-10 04:10:42+00:00      0     NaN
# 9024  1479253655434014723  2024-06-10 04:10:42+00:00      0     NaN
# 9025  1721567191080845312  2024-06-10 04:10:42+00:00      0     NaN
# 9026  1072266549128560641  2024-06-10 04:10:42+00:00      0     NaN
# 9027  1688499149757374464  2024-06-10 04:10:42+00:00      0     NaN
#
#                                                   tweet sentiment
# 0     RT @Surlysimon: @heidimur @davidbewart Daniel ...  Positivo
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9028 entries, 0 to 9027
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     9028 non-null   int64
#  1   created_at  9028 non-null   object
#  2   likes       9028 non-null   int64
#  3   source      0 non-null      float64
#  4   tweet       9028 non-null   object
#  5   sentiment   9028 non-null   object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 423.3+ KB

# %% [markdown]
# ## Eliminar datos

# %% [markdown]
# En este caso eliminaremos **created_at** , **likes**,**source**.

# %%
data = data.drop(['created_at', 'source'], axis=1)

# %%
data
# Out:
#                   user_id  likes  \
# 0     1515220311469621248      0
# 1     1771902488074944512      0
# 2     1075476235449450499      0
# 3              1382805156      0
# 4     1270842720731488265      0
# ...                   ...    ...
# 9023           1730171166      0
# 9024  1479253655434014723      0
# 9025  1721567191080845312      0
# 9026  1072266549128560641      0
# 9027  1688499149757374464      0
#
#                                                   tweet sentiment
# 0     RT @Surlysimon: @heidimur @davidbewart Daniel ...  Positivo
# 1     RT @JesusRPadillaM1: #1x10VictoriaPerfecta TOD...  Positivo
# 2     RT @DRESTRUM__Pl: 🔴 AHORA | Contundente triunf...  Positivo
# 3     RT @gastonedul: La era Scaloni:\n\n70 partidos...  Positivo
# 4                   @QGdaAnitta ANITTA NO FANTÁSTICO ez  Positivo
# ...                                                 ...       ...
# 9023  Nigga in boarding group A talking bout first c...    Neutro
# ...

# %% [markdown]
# En cuanto a la columna **likes**, necesitamos saber el numero total de likes que recibieron los tweetts.

# %%
total_tweets_con_likes = len(data.loc[data['likes'] > 0])

print("Total de tweets que recibieron likes:", total_tweets_con_likes)
# Out:
# Total de tweets que recibieron likes: 53

# %% [markdown]
# Solo 53 tweets recibieron like, ese datos es insignificante frente a 9 mil datos.

# %%
data = data.drop('likes', axis=1)

# %%
data
# Out:
#                   user_id                                              tweet  \
# 0     1515220311469621248  RT @Surlysimon: @heidimur @davidbewart Daniel ...
# 1     1771902488074944512  RT @JesusRPadillaM1: #1x10VictoriaPerfecta TOD...
# 2     1075476235449450499  RT @DRESTRUM__Pl: 🔴 AHORA | Contundente triunf...
# 3              1382805156  RT @gastonedul: La era Scaloni:\n\n70 partidos...
# 4     1270842720731488265                @QGdaAnitta ANITTA NO FANTÁSTICO ez
# ...                   ...                                                ...
# 9023           1730171166  Nigga in boarding group A talking bout first c...
# 9024  1479253655434014723  RT @PatrickAbrazos: Estimado @ZowlOficial, yo ...
# 9025  1721567191080845312  @Doc_Hannibal En un país normal el gobierno no...
# 9026  1072266549128560641  RT @lewdbeef: Normal behavior from these two @...
# 9027  1688499149757374464  RT @dolaricemos: Buena entrevista a Caputo hoy...
#
#      sentiment
# 0     Positivo
# ...

# %% [markdown]
# Tambien debemos eliminar datos duplicados.

# %%
data= data.drop_duplicates(subset=['user_id', 'tweet'])

# %%
data
# Out:
#                   user_id                                              tweet  \
# 0     1515220311469621248  RT @Surlysimon: @heidimur @davidbewart Daniel ...
# 1     1771902488074944512  RT @JesusRPadillaM1: #1x10VictoriaPerfecta TOD...
# 2     1075476235449450499  RT @DRESTRUM__Pl: 🔴 AHORA | Contundente triunf...
# 3              1382805156  RT @gastonedul: La era Scaloni:\n\n70 partidos...
# 4     1270842720731488265                @QGdaAnitta ANITTA NO FANTÁSTICO ez
# ...                   ...                                                ...
# 8831   924395315389661186  RT @lowbimbo: coisa mais normal do mundo é mul...
# 8832            469296197  RT @thejackhopkins: We can’t just sit back and...
# 8833            881021172  RT @camilaswet9511: Ya tenemos citas para el m...
# 8834   724241069173542914  @jimeflor4 Yo confío 100% en nosotros. Estoy c...
# 8835            215408018  RT @Intidelaho2: Dizque Petro esta ahuyentando...
#
#      sentiment
# 0     Positivo
# ...

# %% [markdown]
# **Paso 1: Eliminar las URL**<BR>
# Los localizadores uniformes de recursos (URL) son direcciones web que suelen aparecer en el texto. Por lo general, no brindan información significativa sobre el sentimiento y se pueden eliminar para que el texto se centre más en el contenido en sí.

# %%
import re

def remove_urls(text):
    return re.sub(r'http\S+', '', text)

data['tweet'] = data['tweet'].apply(remove_urls)
# Out:
# <ipython-input-129-372adf5c2b02>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['tweet'] = data['tweet'].apply(remove_urls)

# %% [markdown]
# **Paso 2: Manejo de Emojis**
#
# Los emojis son símbolos gráficos que pueden transmitir emociones. Puedes optar por conservar, eliminar o reemplazar emojis con sus equivalentes textuales (por ejemplo, convertir 😊 en "sonrisa"). La elección depende de si desea incorporar el sentimiento emoji en su análisis.

# %%
import emoji
from multiprocessing import Pool

emoji_dict = {
    '😊': 'alegre',
    '😂': 'sonriente',
    '❤️': 'amor',
    '😢': 'triste',
    '😭': 'tristeza'
}

def replace_emojis(text):
    for emoji_code, emoji_text in emoji_dict.items():
        text = text.replace(emoji_code, f' {emoji_text} ')

    # Eliminar los emojis no definidos en el diccionario
    text = ''.join(char for char in text if not emoji.is_emoji(char))

    return text

def process_tweets(data):
    data['tweet_con_emoji_text'] = data['tweet'].apply(replace_emojis)
    return data

if __name__ == '__main__':

    # Dividir los datos en chunks para procesarlos en paralelo
    chunk_size = len(data) // 4  # Ajusta el número de chunks según tus necesidades
    chunks = [data[i:i+chunk_size] for i in range(0, len(data), chunk_size)]

    # Crear un pool de procesos
    pool = Pool()

    # Procesar los chunks en paralelo
    results = pool.map(process_tweets, chunks)

    # Combinar los resultados en un solo dataframe
    processed_data = pd.concat(results)

    # Cerrar el pool de procesos
    pool.close()
    pool.join()

# %%
processed_data
# Out:
#                   user_id                                              tweet  \
# 0     1515220311469621248  RT @Surlysimon: @heidimur @davidbewart Daniel ...
# 1     1771902488074944512  RT @JesusRPadillaM1: #1x10VictoriaPerfecta TOD...
# 2     1075476235449450499  RT @DRESTRUM__Pl: 🔴 AHORA | Contundente triunf...
# 3              1382805156  RT @gastonedul: La era Scaloni:\n\n70 partidos...
# 4     1270842720731488265                @QGdaAnitta ANITTA NO FANTÁSTICO ez
# ...                   ...                                                ...
# 8831   924395315389661186  RT @lowbimbo: coisa mais normal do mundo é mul...
# 8832            469296197  RT @thejackhopkins: We can’t just sit back and...
# 8833            881021172  RT @camilaswet9511: Ya tenemos citas para el m...
# 8834   724241069173542914  @jimeflor4 Yo confío 100% en nosotros. Estoy c...
# 8835            215408018  RT @Intidelaho2: Dizque Petro esta ahuyentando...
#
# ...

# %% [markdown]
# En este caso necesitamos eliminar la columna **tweet**

# %%
data = processed_data.drop('tweet', axis=1)

# %%
data
# Out:
#                   user_id sentiment  \
# 0     1515220311469621248  Positivo
# 1     1771902488074944512  Positivo
# 2     1075476235449450499  Positivo
# 3              1382805156  Positivo
# 4     1270842720731488265  Positivo
# ...                   ...       ...
# 8831   924395315389661186    Neutro
# 8832            469296197    Neutro
# 8833            881021172    Neutro
# 8834   724241069173542914    Neutro
# 8835            215408018    Neutro
#
#                                    tweet_con_emoji_text
# 0     RT @Surlysimon: @heidimur @davidbewart Daniel ...
# 1     RT @JesusRPadillaM1: #1x10VictoriaPerfecta TOD...
# 2     RT @DRESTRUM__Pl:  AHORA | Contundente triunfo...
# 3     RT @gastonedul: La era Scaloni:\n\n70 partidos...
# 4                   @QGdaAnitta ANITTA NO FANTÁSTICO ez
# ...                                                 ...
# 8831  RT @lowbimbo: coisa mais normal do mundo é mul...
# 8832  RT @thejackhopkins: We can’t just sit back and...
# ...

# %% [markdown]
# **Paso 3: Eliminacion de @,# y RT**

# %%
import pandas as pd
import re

data['text_sin_'] = data['tweet_con_emoji_text'].str.replace(r'@\w+', '', regex=True)

# %%
data
# Out:
#                   user_id sentiment  \
# 0     1515220311469621248  Positivo
# 1     1771902488074944512  Positivo
# 2     1075476235449450499  Positivo
# 3              1382805156  Positivo
# 4     1270842720731488265  Positivo
# ...                   ...       ...
# 8831   924395315389661186    Neutro
# 8832            469296197    Neutro
# 8833            881021172    Neutro
# 8834   724241069173542914    Neutro
# 8835            215408018    Neutro
#
#                                    tweet_con_emoji_text  \
# 0     RT @Surlysimon: @heidimur @davidbewart Daniel ...
# 1     RT @JesusRPadillaM1: #1x10VictoriaPerfecta TOD...
# 2     RT @DRESTRUM__Pl:  AHORA | Contundente triunfo...
# 3     RT @gastonedul: La era Scaloni:\n\n70 partidos...
# 4                   @QGdaAnitta ANITTA NO FANTÁSTICO ez
# ...                                                 ...
# 8831  RT @lowbimbo: coisa mais normal do mundo é mul...
# 8832  RT @thejackhopkins: We can’t just sit back and...
# ...

# %%
data['text_limpio'] = data['text_sin_'].str.replace(r'(#\w+|RT\s:)', '', regex=True)

# %%
data
# Out:
#                   user_id sentiment  \
# 0     1515220311469621248  Positivo
# 1     1771902488074944512  Positivo
# 2     1075476235449450499  Positivo
# 3              1382805156  Positivo
# 4     1270842720731488265  Positivo
# ...                   ...       ...
# 8831   924395315389661186    Neutro
# 8832            469296197    Neutro
# 8833            881021172    Neutro
# 8834   724241069173542914    Neutro
# 8835            215408018    Neutro
#
#                                    tweet_con_emoji_text  \
# 0     RT @Surlysimon: @heidimur @davidbewart Daniel ...
# 1     RT @JesusRPadillaM1: #1x10VictoriaPerfecta TOD...
# 2     RT @DRESTRUM__Pl:  AHORA | Contundente triunfo...
# 3     RT @gastonedul: La era Scaloni:\n\n70 partidos...
# 4                   @QGdaAnitta ANITTA NO FANTÁSTICO ez
# ...                                                 ...
# 8831  RT @lowbimbo: coisa mais normal do mundo é mul...
# 8832  RT @thejackhopkins: We can’t just sit back and...
# ...

# %%
data = data.drop(['tweet_con_emoji_text', 'text_sin_'], axis=1)

# %%
data
# Out:
#                   user_id sentiment  \
# 0     1515220311469621248  Positivo
# 1     1771902488074944512  Positivo
# 2     1075476235449450499  Positivo
# 3              1382805156  Positivo
# 4     1270842720731488265  Positivo
# ...                   ...       ...
# 8831   924395315389661186    Neutro
# 8832            469296197    Neutro
# 8833            881021172    Neutro
# 8834   724241069173542914    Neutro
# 8835            215408018    Neutro
#
#                                             text_limpio
# 0        Daniel Andrews won three elections and serv...
# 1       TODAS Y TODOS LOS REVOLUCIONARIOS, con la Ve...
# 2       AHORA | Contundente triunfo de Daniel Reyes ...
# 3      La era Scaloni:\n\n70 partidos. 49 victorias,...
# 4                               ANITTA NO FANTÁSTICO ez
# ...                                                 ...
# 8831   coisa mais normal do mundo é mulher bonita co...
# 8832   We can’t just sit back and stay silent when t...
# ...

# %% [markdown]
# Ahora solo necesitimos la columna **user_id**,**sentiment** y **texto_limpio**.

# %%
data
# Out:
#                   user_id sentiment  \
# 0     1515220311469621248  Positivo
# 1     1771902488074944512  Positivo
# 2     1075476235449450499  Positivo
# 3              1382805156  Positivo
# 4     1270842720731488265  Positivo
# ...                   ...       ...
# 8831   924395315389661186    Neutro
# 8832            469296197    Neutro
# 8833            881021172    Neutro
# 8834   724241069173542914    Neutro
# 8835            215408018    Neutro
#
#                                             text_limpio
# 0        Daniel Andrews won three elections and serv...
# 1       TODAS Y TODOS LOS REVOLUCIONARIOS, con la Ve...
# 2       AHORA | Contundente triunfo de Daniel Reyes ...
# 3      La era Scaloni:\n\n70 partidos. 49 victorias,...
# 4                               ANITTA NO FANTÁSTICO ez
# ...                                                 ...
# 8831   coisa mais normal do mundo é mulher bonita co...
# 8832   We can’t just sit back and stay silent when t...
# ...

# %%
data.to_csv('Data_preprocesados_actual.csv', index=False)
